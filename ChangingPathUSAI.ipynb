# %%
import pandas as pd
import os
df = pd.read_csv(r'/home/jupyter/csvFile/Traindf_fold2_5.csv')
print('Data tatal:',len(df))
df.head()
# Out:
# Data tatal: 23219
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Case  \
# 0           0             4               4                 4    15
# 1           1             5               5                 5    15
# 2           2            21              21                21    22
# 3           3            22              22                22    22
# 4           4            32              32                32    25
#
#   Abs Position Sub Position     Class Sub_class  \
# 0           P2           P2  Abnormal      AB03
# 1           P1           P1  Abnormal      AB03
# 2           P1           P1  Abnormal      AB03
# 3           P2           P2  Abnormal      AB03
# 4           P2           P2  Abnormal      AB03
#
#                                            Path Full  ...   left    top  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  ...   45.0  187.0
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  ...    0.0  184.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23219 entries, 0 to 23218
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        23219 non-null  int64
#  1   Unnamed: 0.1      23219 non-null  int64
#  2   Unnamed: 0.1.1    23219 non-null  int64
#  3   Unnamed: 0.1.1.1  23219 non-null  int64
#  4   Case              23219 non-null  int64
#  5   Abs Position      23219 non-null  object
#  6   Sub Position      23219 non-null  object
#  7   Class             23219 non-null  object
#  8   Sub_class         23219 non-null  object
#  9   Path Full         23219 non-null  object
#  10  Path Crop         23219 non-null  object
#  11  Views             23219 non-null  object
#  12  fold              23219 non-null  int64
#  13  tagName           23219 non-null  object
#  14  originalImage     16184 non-null  object
#  15  left              16184 non-null  float64
# ...

# %%
Path = df['Path Crop'].tolist()
aa = []
for i in range(len(Path)):
    a = Path[i].split('/')
    if len(a) == 10:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]
    else:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]+'/'+a[10]
    aa.append(a)

# %%
df['PathG']=aa
os.chdir( '/home/jupyter/csvFile/')
df.to_csv('GTraindf_fold2_5.csv')

# %%
df = pd.read_csv(r'/home/jupyter/csvFile/Validationdf_fold2_5.csv')
print('Data tatal:',len(df))

Path = df['Path Crop'].tolist()

aa = []
for i in range(len(Path)):
    a = Path[i].split('/')
    if len(a) == 10:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]
    else:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]+'/'+a[10]
    aa.append(a) 
    
df['PathG']=aa
os.chdir( '/home/jupyter/csvFile/')
df.to_csv('GValidationdf_fold2_5.csv')
# Out:
# Data tatal: 3712

# %%
df = pd.read_csv(r'/home/jupyter/csvFile/Traindf_fold1_5.csv')
print('Data tatal:',len(df))

Path = df['Path Crop'].tolist()

aa = []
for i in range(len(Path)):
    a = Path[i].split('/')
    if len(a) == 10:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]
    else:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]+'/'+a[10]
    aa.append(a) 
    
df['PathG']=aa
os.chdir( '/home/jupyter/csvFile/')
df.to_csv('GTraindf_fold1_5.csv')
# Out:
# Data tatal: 23280

# %%
df = pd.read_csv(r'/home/jupyter/csvFile/Validationdf_fold1_5.csv')
print('Data tatal:',len(df))

Path = df['Path Crop'].tolist()

aa = []
for i in range(len(Path)):
    a = Path[i].split('/')
    if len(a) == 10:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]
    else:
        a = '/home/jupyter/'+a[3]+'/'+a[4]+'/'+a[5]+'/'+a[6]+'/'+a[7]+'/'+a[8]+'/'+a[9]+'/'+a[10]
    aa.append(a) 
    
df['PathG']=aa
os.chdir( '/home/jupyter/csvFile/')
df.to_csv('GValidationdf_fold1_5.csv')
# Out:
# Data tatal: 3089

# %%
#load image origin save to test.jpg
import cv2
from IPython.display import Image
img_path = '/home/jupyter/HDD/VISION_dataset/USAI/ABnormal01/3 ABNORMAL/cropped/AB03 P2 C015.JPG'
img_c = cv2.imread(img_path)
Image(filename=img_path)
