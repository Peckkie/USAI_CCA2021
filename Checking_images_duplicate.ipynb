# %%
import pandas as pd
df = pd.read_csv( '/home/yupaporn/codes/USAI/Testdf.csv')
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0         111           111    40           P1           P1  Abnormal
# 1         112           112    40           P2           P2  Abnormal
# 2         113           113    40           P4          P41  Abnormal
#
#   Sub_class                                          Path Full  \
# 0      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  ...  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A  ...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A  ...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B  ...
#
#                                        originalImage   left    top  width  \
# 0  https://irisprodseatraining.blob.core.windows....   86.0  133.0  477.0
# ...

# %%
filename = list(set(df['filename']))
a_ =[]
for i in filename:
    a = len(df[df['filename'] == i ])
    a_.append(a)

filename__=[]
aa__ =[]
for i in range(len(a_)):
    if a_[i] >=2:
        filename_ = filename[i]
        aa_ = a_[i]
        filename__.append(filename_)
        aa__.append(aa_)
df_ = pd.DataFrame(list(zip(filename__, aa__)),columns =['FileName', 'Count'])
df_
# Out:
#         FileName  Count
# 0     P2C103.jpg      2
# 1   P5.1C150.jpg      2
# 2     P2C140.jpg      2
# 3     P8C150.jpg      2
# 4     P2C121.jpg      2
# 5     P2C150.jpg      4
# 6   P7.2C150.jpg      2
# 7     P2C122.jpg      2
# 8   P3.1C150.jpg      2
# 9   P4.2C150.jpg      2
# 10    P2C142.jpg      2
# 11    P2C143.jpg      2
# 12  P5.2C150.jpg      2
# 13    P2C123.jpg      2
# 14    P2C101.jpg      2
# 15    P6C150.jpg      2
# 16  P7.1C150.jpg      2
# 17    P2C120.jpg      2
# 18    P1C150.jpg      2
# 19    P2C102.jpg      2
# 20    P2C141.jpg      2
# 21  P4.1C150.jpg      2

# %%
a = df[df['filename'] == 'P2C150.jpg']
a
# Out:
#      Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position   Class  \
# 716        3670          3670   150           P2           P2  Normal
# 718        3672          3672   150           P2          P32  Normal
# 727        3681          3681   150           P2           P8  Normal
# 729        3683          3683   150           P2           P2  Normal
#
#     Sub_class                                          Path Full  \
# 716    Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 718    Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 727    Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
# 729    Normal  /media/tohn/HDD/VISION_dataset/USAI/US images ...
#
#                                              Path Crop Views  ...  \
# 716  /media/tohn/HDD/VISION_dataset/USAI/US images ...  FP-A  ...
# 718  /media/tohn/HDD/VISION_dataset/USAI/US images ...  FP-A  ...
# 727  /media/tohn/HDD/VISION_dataset/USAI/US images ...  FP-A  ...
# ...

# %%
from IPython.display import Image
import cv2
import numpy as np

# %%
pathj = a[a['Path Full'] != path[i]]['Path Full'].tolist()
pathj
# Out:
# ['/media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P3.2 C101-C150/P2C150.jpg',
#  '/media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P8 C101-C150/P2C150.jpg',
#  '/media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.4/P2 C150-C200/P2C150.jpg']

# %%
path = a['Path Full'].tolist()
for i in range(len(a)):
#     img = cv2.imread(path[i]) 
    pathj = a[a['Path Full'] != path[i]]['Path Full'].tolist()
    for j in range(len(pathj)):
        print(i,j)
        img = cv2.imread(path[i])
        img_c = cv2.imread(pathj[j]) 
        img_dif = np.sum(img-img_c)
        if np.sum(img-img_c) == 0:
            path_ = path[j]
            print(path_)
        else:
            path_ = 'None'
            print('this is none')
# Out:
# 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-75ecd66a83e6> in <module>
#       7         img = cv2.imread(path[i])
#       8         img_c = cv2.imread(pathj[j])
# ----> 9         img_dif = np.sum(img-img_c)
#      10         if np.sum(img-img_c) == 0:
#      11             path_ = path[j]
#
# ValueError: operands could not be broadcast together with shapes (1125,1500,3) (1125,1499,3)

# %%
for record in a.iterrows():
    print(record[1]['Path Full'])
    img = cv2.imread(path[i])
# Out:
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P2 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P3.2 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P8 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.4/P2 C150-C200/P2C150.jpg

# %%
path = a['Path Full'].tolist()
img = cv2.imread(path[0])
img_c = cv2.imread(path[3]) 
img_dif = np.sum(img-img_c)
print(img_dif)
# Out:
# 209207561

# %%
path = a['Path Full'].tolist()
img = cv2.imread(path[0])
img_c = cv2.imread(path[1])
 
# dim = (1500, 1125)
# img_c = cv2.resize(img_c, dim, interpolation = cv2.INTER_AREA)

img_dif = np.sum(img-img_c)
print(img_dif)
# Out:
# 317858596

# %%
dim = (1500, 1125)
img_c = cv2.resize(img_c, dim, interpolation = cv2.INTER_AREA)

# %%
img.shape
# Out:
# (1125, 1500, 3)

# %%
(img-img_c).shape
# Out:
# (1125, 1499, 3)

# %%
from IPython.display import Image
import cv2
# img_c = cv2.imread(img)
# img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 5)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img-img_c)

# %%
from IPython.display import Image
import cv2
# img_c = cv2.imread(img)
# img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 5)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img_c)

# %%
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
def compare_images(imageA, imageB, title):
	# compute the mean squared error and structural similarity
	# index for the images
	m = mse(imageA, imageB)
	s = ssim(imageA, imageB,multichannel=True)
	# setup the figure
	fig = plt.figure(title)
	plt.suptitle("MSE: %.2f, SSIM: %.2f" % (m, s))
	# show first image
	ax = fig.add_subplot(1, 2, 1)
	plt.imshow(imageA, cmap = plt.cm.gray)
	plt.axis("off")
	# show the second image
	ax = fig.add_subplot(1, 2, 2)
	plt.imshow(imageB, cmap = plt.cm.gray)
	plt.axis("off")
	# show the images
	plt.show()

# %%
# # initialize the figure
# fig = plt.figure("Images")
# images = ("Original", original), ("Contrast", contrast), ("Photoshopped", shopped)
# # loop over the images
# for (i, (name, image)) in enumerate(images):
# 	# show the image
# 	ax = fig.add_subplot(1, 3, i + 1)
# 	ax.set_title(name)
# 	plt.imshow(image, cmap = plt.cm.gray)
# 	plt.axis("off")
# # show the figure
# plt.show()
# compare the images
compare_images(original, original, "Original vs. Original")
compare_images(original, contrast, "Original vs. Contrast")
compare_images(original, shopped, "Original vs. Photoshopped")

# %%
# import the necessary packages
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread(path[0])
img_c = cv2.imread(path[1]) 

dim = (1500, 1125)
img_c = cv2.resize(img_c, dim, interpolation = cv2.INTER_AREA)

compare_images(img, img_c, "Original vs. Original")

# %%
ssim(img, img_c,multichannel=True)
# Out:
# 0.8877097744376359

# %%
img[:, :, 0].shape
# Out:
# (1125, 1500)

# %%
img[:, :, 1].shape
# Out:
# (1125, 1500)

# %%
img[:, :, 2].shape
# Out:
# (1125, 1500)

# %%
path = a['Path Full'].tolist()

# %%
import imageio
image = imageio.imread(path[0])

red_image = image.copy()
red_image[:, :, 0] = 0
red_image[:, :, 1] = 0
imageio.imwrite('blue_image.jpg', red_image)

red_image = image.copy()
red_image[:, :, 1] = 0
red_image[:, :, 2] = 0
imageio.imwrite('red_image.jpg', red_image)

red_image = image.copy()
red_image[:, :, 0] = 0
red_image[:, :, 2] = 0
imageio.imwrite('green_image.jpg', red_image)

# %%
import imageio
image = imageio.imread(path[3])

red_image = image.copy()
red_image[:, :, 0] = 0
red_image[:, :, 1] = 0
imageio.imwrite('blue_image_c.jpg', red_image)

red_image = image.copy()
red_image[:, :, 1] = 0
red_image[:, :, 2] = 0
imageio.imwrite('red_image_c.jpg', red_image)

red_image = image.copy()
red_image[:, :, 0] = 0
red_image[:, :, 2] = 0
imageio.imwrite('green_image_c.jpg', red_image)

# %%
im_c = ['/home/yupaporn/codes/USAI_CCA2021/blue_image_c.jpg',
'/home/yupaporn/codes/USAI_CCA2021/red_image_c.jpg',
'/home/yupaporn/codes/USAI_CCA2021/green_image.jpg']
im = ['/home/yupaporn/codes/USAI_CCA2021/blue_image.jpg',
'/home/yupaporn/codes/USAI_CCA2021/red_image.jpg',
'/home/yupaporn/codes/USAI_CCA2021/green_image.jpg']

# %%
for k in range(3):
# k =2
    img = cv2.imread(im[k])
    img_c = cv2.imread(im_c[k]) 
    compare_images(img, img_c, "Original vs. Original")

# %%
img = cv2.imread(im[1])
img_c = cv2.imread(im_c[0]) 
compare_images(img, img_c, "Original vs. Original")

# %%
# imageio.imwrite('red.jpg', image[:, :, 0])
# imageio.imwrite('green.jpg', image[:, :, 1])
# imageio.imwrite('blue.jpg', image[:, :, 2])

# %%
# !pwd
# Out:
# /home/yupaporn/codes/USAI_CCA2021

# %%
import skimage.io as io
import matplotlib.pyplot as plt

# Read
img =img

# Split
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# Plot
fig, axs = plt.subplots(2,2)

cax_00 = axs[0,0].imshow(img)
axs[0,0].xaxis.set_major_formatter(plt.NullFormatter())  # kill xlabels
axs[0,0].yaxis.set_major_formatter(plt.NullFormatter())  # kill ylabels

cax_01 = axs[0,1].imshow(red, cmap='Reds')
fig.colorbar(cax_01, ax=axs[0,1])
axs[0,1].xaxis.set_major_formatter(plt.NullFormatter())
axs[0,1].yaxis.set_major_formatter(plt.NullFormatter())

cax_10 = axs[1,0].imshow(green, cmap='Greens')
fig.colorbar(cax_10, ax=axs[1,0])
axs[1,0].xaxis.set_major_formatter(plt.NullFormatter())
axs[1,0].yaxis.set_major_formatter(plt.NullFormatter())

cax_11 = axs[1,1].imshow(blue, cmap='Blues')
fig.colorbar(cax_11, ax=axs[1,1])
axs[1,1].xaxis.set_major_formatter(plt.NullFormatter())
axs[1,1].yaxis.set_major_formatter(plt.NullFormatter())
plt.show()

# Plot histograms
fig, axs = plt.subplots(3, sharex=True, sharey=True)

axs[0].hist(red.ravel(), bins=10)
axs[0].set_title('Red')
axs[1].hist(green.ravel(), bins=10)
axs[1].set_title('Green')
axs[2].hist(blue.ravel(), bins=10)
axs[2].set_title('Blue')

plt.show()

# %%
axs[0].hist(red.ravel(), bins=10)
axs[0].set_title('Red')
axs[1].hist(green.ravel(), bins=10)
axs[1].set_title('Green')
axs[2].hist(blue.ravel(), bins=10)
axs[2].set_title('Blue')

# %%
red.ravel()
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
import skimage.io as io
import matplotlib.pyplot as plt

# Read
img =img_c

# Split
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# Plot
fig, axs = plt.subplots(2,2)

cax_00 = axs[0,0].imshow(img)
axs[0,0].xaxis.set_major_formatter(plt.NullFormatter())  # kill xlabels
axs[0,0].yaxis.set_major_formatter(plt.NullFormatter())  # kill ylabels

cax_01 = axs[0,1].imshow(red, cmap='Reds')
fig.colorbar(cax_01, ax=axs[0,1])
axs[0,1].xaxis.set_major_formatter(plt.NullFormatter())
axs[0,1].yaxis.set_major_formatter(plt.NullFormatter())

cax_10 = axs[1,0].imshow(green, cmap='Greens')
fig.colorbar(cax_10, ax=axs[1,0])
axs[1,0].xaxis.set_major_formatter(plt.NullFormatter())
axs[1,0].yaxis.set_major_formatter(plt.NullFormatter())

cax_11 = axs[1,1].imshow(blue, cmap='Blues')
fig.colorbar(cax_11, ax=axs[1,1])
axs[1,1].xaxis.set_major_formatter(plt.NullFormatter())
axs[1,1].yaxis.set_major_formatter(plt.NullFormatter())
plt.show()

# Plot histograms
fig, axs = plt.subplots(3, sharex=True, sharey=True)

axs[0].hist(red.ravel(), bins=10)
axs[0].set_title('Red')
axs[1].hist(green.ravel(), bins=10)
axs[1].set_title('Green')
axs[2].hist(blue.ravel(), bins=10)
axs[2].set_title('Blue')

plt.show()

# %%
path = a['Path Full'].tolist()
img = cv2.imread(path[0])
img = cv2.imread(path[3]) 
img_dif = np.sum(img-img_c)
print(img_dif)
# if np.sum(img-img_c) == 0:
#     print(img_dif)
# Out:
# 0

# %%
def findmat (a):
    for record in a.iterrows():
        img_path = record[1]['Path Full']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')

# %%
for record in a.iterrows():
    print(record[1]['Path Full'])
    img = cv2.imread(path[i])
# Out:
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P2 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P3.2 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P8 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.4/P2 C150-C200/P2C150.jpg

# %%
path = a['Path Full'].tolist()
# img = cv2.imread(path[0]) 
for i in range(0,len(path)):
    img = cv2.imread(path[i]) 
    path = findmat(a)
    print(path)
# Out:
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P2 C101-C150/P2C150.jpg
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P2 C101-C150/P2C150.jpg
# this is none
# this is none
# this is none
# this is none
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ef57daea0d23> in <module>
#       2 # img = cv2.imread(path[0])
#       3 for i in range(0,len(path)):
# ----> 4     img = cv2.imread(path[i])
#       5     path = findmat(a)
#       6     print(path)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
path = a['Path Full'].tolist()
for i in range(len(a)):
    img = cv2.imread(path[i]) 
    for j in range(len(a)):
        img_c = cv2.imread(path[j]) 
        if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
            img_dif = np.sum(img-img_c)
            path_ = 'None'
            if img_dif == 0:
                print(i)
                path_ = path[j]
                print(path_)
            else:
                path_ = 'None'
                print('this is none')
# Out:
# 0
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P2 C101-C150/P2C150.jpg
# this is none
# this is none
# this is none
# this is none
# 1
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P3.2 C101-C150/P2C150.jpg
# this is none
# this is none
# this is none
# this is none
# 2
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.3/P8 C101-C150/P2C150.jpg
# this is none
# this is none
# this is none
# this is none
# 3
# /media/tohn/HDD/VISION_dataset/USAI/US images for AI-1.4/P2 C150-C200/P2C150.jpg

# %%
path = a['Path Full'].tolist()
for i in range(len(a)):
    img = cv2.imread(path[i]) 
    for j in range(len(a)):
        img_c = cv2.imread(path[j]) 
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                print(path)
        except:
            path = 'None'
            print('this is none')
# Out:
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none
# this is none

# %%
from IPython.display import Image
import cv2
# img_c = cv2.imread(img)
# img_c = cv2.rectangle(img_c, (left,top), (left+width,top+height), (255,0,0), 5)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 15]
plt.imshow(img)

# %%
def findmat (thisdf):
    for record in thisdf.iterrows():
        img_path = record[1]['Path']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/USAI3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Path'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-2d62bf1df308> in <module>
# ...

# %%
def findmat (thisdf):
    for record in thisdf.iterrows():
        img_path = record[1]['Path Full']
        img_c = cv2.imread(img_path)
        try:
            if (img_c.shape[0] == img.shape[0]) and (img_c.shape[1] == img.shape[1]):
                img_dif = np.sum(img-img_c)
                path = 'None'
                if img_dif == 0:
                    print(img_path)
                    path = img_path
                return path
        except:
            path = 'None'
            print('this is none')
